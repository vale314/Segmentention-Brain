# %% [markdown]
# <a href="https://colab.research.google.com/github/vale314/Segmentention-Brain/blob/test/Entendimiento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Graficos embebidos.
# %matplotlib inline

# %%
import numpy as np #importando numpy
from scipy import stats # importando scipy.stats
import matplotlib.pyplot as plt # importando matplotlib
import seaborn as sns # importando seaborn
import seaborn as sb


# parámetros estéticos de seaborn
sns.set_palette("deep", desat=.6)
sns.set_context(rc={"figure.figsize": (8, 4)})

# %%
# Trabajando con una ruta relativa
path = './drive/MyDrive/Dataset/' 

# Colocamos en una variable el archivo a trabajar
archivo = 'participants.csv'

# %%
# Paquete requerido para listar los archivos del directorio
from os import listdir

# %%
import pandas as pd

# %%
Files = []
for File in listdir(path):
    # Escribir la RUTA COMPLETA de cada archivo
    Files.append(File)

# %%
Files
# Out:
# ['anat',
#  'dataset_description.json',
#  'participants.json',
#  'Copia de participants.tsv',
#  'participants.csv']

# %%
df = pd.read_csv(path+archivo, index_col=0)

# %%
df.shape
# Out:
# (145, 26)

# %%
df.head()
# Out:
#                  group  sex   age  educ  educ_yr  occup income  civil_st  \
#  participant_id
# sub-001            1.0  1.0  41.0   7.0     22.0    7.0  20000       1.0
# sub-002            2.0  1.0  23.0   5.0     16.0    3.0   7100       6.0
# sub-003            2.0  1.0  27.0   5.0     16.0    4.0  12000       6.0
# sub-004            1.0  1.0  27.0   5.0     16.0    7.0  10000       6.0
# sub-005            1.0  1.0  23.0   5.0     16.0    7.0   6000       6.0
#
#                  child  child_num  ...  admin.route  years.begin  \
#  participant_id                    ...
# sub-001            0.0        0.0  ...          0.0          0.0
# sub-002            0.0        0.0  ...          2.0          5.0
# sub-003            0.0        0.0  ...          2.0          9.0
# sub-004            0.0        0.0  ...          0.0          0.0
# sub-005            0.0        0.0  ...          0.0          0.0
#
#                  coc.age.onset  days.last.use  week.dose  tobc.lastyear  \
# ...

# %%
pearsoncorr = df.corr(method='pearson')
pearsoncorr
# Out:
#                     group       sex       age      educ   educ_yr     occup  \
# group            1.000000 -0.078466  0.025290 -0.214269 -0.221497  0.004907
# sex             -0.078466  1.000000  0.067150  0.109529  0.104665 -0.253260
# age              0.025290  0.067150  1.000000  0.003489  0.009092  0.039608
# educ            -0.214269  0.109529  0.003489  1.000000  0.994730  0.139666
# educ_yr         -0.221497  0.104665  0.009092  0.994730  1.000000  0.139837
# occup            0.004907 -0.253260  0.039608  0.139666  0.139837  1.000000
# civil_st        -0.015798  0.003072 -0.362015  0.218307  0.222988  0.077720
# child            0.162775  0.044268  0.405376 -0.275196 -0.278837  0.069189
# child_num        0.081989  0.105910  0.471844 -0.305931 -0.310205  0.059954
# work_thirtydays  0.155125  0.281105 -0.041748  0.003105  0.000365 -0.258550
# work_threeyears  0.125328  0.377531 -0.089746  0.108054  0.103491 -0.147225
# ...

# %%
fig, ax = plt.subplots(figsize=(15,15))         # Sample figsize in inches

sb.heatmap(pearsoncorr, 
            xticklabels=pearsoncorr.columns,
            yticklabels=pearsoncorr.columns,
            cmap='RdBu_r',
            annot=True,
            linewidths=.5,
            ax=ax
            )
